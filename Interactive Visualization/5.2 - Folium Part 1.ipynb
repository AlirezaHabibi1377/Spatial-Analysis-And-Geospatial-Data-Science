# %% [markdown]
# # <h1><center>Spatial Data Visualization</center></h1>
# ## 5.2 - Interactive Maps with Folium - Part I

# %%
import geopandas as gpd
import folium

# %%
# Countries
countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Conflict Dataset Points
acled = gpd.read_file(
    "data/acled2019.shp",
    mask = countries[countries["continent"] == "Africa"]
)
# Out:
# <ipython-input-2-ed70da355b3f>:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
acled.head()
# Out:
#    data_id  iso event_id_c  event_id_n        event_date  year  time_preci  \
# 0  6714129  706   SOM30213       30213  31 December 2019  2019           1
# 1  6723349   12    ALG7951        7951  31 December 2019  2019           1
# 2  6723350   12    ALG7953        7953  31 December 2019  2019           1
# 3  6713368  404    KEN7182        7182  31 December 2019  2019           1
# 4  6718756  180   DRC16324       16324  31 December 2019  2019           1
#
#                    event_type        sub_event_  \
# 0                     Battles       Armed clash
# 1                    Protests  Peaceful protest
# 2                    Protests  Peaceful protest
# 3  Violence against civilians            Attack
# 4                     Battles       Armed clash
#
#                                               actor1  ... latitude  longitude  \
# 0                                         Al Shabaab  ...   2.3963    45.0159
# 1                               Protesters (Algeria)  ...  36.7525     3.0420
# 2                               Protesters (Algeria)  ...  36.3650     6.6147
# 3                     Police Forces of Kenya (2013-)  ...  -3.3543    40.0209
# 4  Military Forces of Democratic Republic of Cong...  ...  -1.1869    29.4461
#
#   geo_precis                                             source  \
# 0          1                                 Undisclosed Source
# 1          1  Liberte (Algeria); TSA Algerie; El Watan (Alge...
# 2          1              Liberte (Algeria); El Watan (Algeria)
# 3          1                               Daily Nation (Kenya)
# 4          2                              Kivu Security Tracker
#
#             source_sca                                              notes  \
# 0  Local partner-Other  31 December 2019. In Warmahan, Al Shabaab mili...
# 1             National  On 31 December 2019, students held their 45th ...
# 2             National  On 31 December 2019, students held their 45th ...
# 3             National  On December 31 2019, a suspected Al Shabaab re...
# 4  Local partner-Other  On 31 December 2019, the FARDC attacked Mayi M...
#
#   fatalities   timestamp iso3                   geometry
# 0          0  1578512393  SOM   POINT (45.01590 2.39630)
# 1          0  1579554007  DZA   POINT (3.04200 36.75250)
# 2          0  1579554007  DZA   POINT (6.61470 36.36500)
# 3          1  1578512391  KEN  POINT (40.02090 -3.35430)
# 4          0  1578943802  COD  POINT (29.44610 -1.18690)
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Base maps, Markers & Icons

# %%
m = folium.Map(location=[53.431085, -2.960422])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_720591ce9b7b8c5a83c1ec874c0b2867 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_720591ce9b7b8c5a83c1ec874c0b2867&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_720591ce9b7b8c5a83c1ec874c0b2867 = L.map(
#                 &quot;map_720591ce9b7b8c5a83c1ec874c0b2867&quot;,
#                 {
#                     center: [53.431085, -2.960422],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72f74c0fa07f464bd788c88bb0aef100 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_720591ce9b7b8c5a83c1ec874c0b2867);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Zoom
m = folium.Map(location=[53.431085, -2.960422], zoom_start=7)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_899f9063ef13d800fec60836ae449a5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_899f9063ef13d800fec60836ae449a5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_899f9063ef13d800fec60836ae449a5f = L.map(
#                 &quot;map_899f9063ef13d800fec60836ae449a5f&quot;,
#                 {
#                     center: [53.431085, -2.960422],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3c26d8630a30e13d3713eb884f46d49 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_899f9063ef13d800fec60836ae449a5f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Change Base map
m = folium.Map(location=[53.431085, -2.960422], tiles="CartoDB dark_matter", zoom_start=15)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_084363675bb76eb7448fe9d8bcfd58c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_084363675bb76eb7448fe9d8bcfd58c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_084363675bb76eb7448fe9d8bcfd58c1 = L.map(
#                 &quot;map_084363675bb76eb7448fe9d8bcfd58c1&quot;,
#                 {
#                     center: [53.431085, -2.960422],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ddb3bd41be77d356a44574a558b92a7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_084363675bb76eb7448fe9d8bcfd58c1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker(
    location=[53.432018, -2.957987], 
    popup='<i>Stanley Park</i>'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_084363675bb76eb7448fe9d8bcfd58c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_084363675bb76eb7448fe9d8bcfd58c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_084363675bb76eb7448fe9d8bcfd58c1 = L.map(
#                 &quot;map_084363675bb76eb7448fe9d8bcfd58c1&quot;,
#                 {
#                     center: [53.431085, -2.960422],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ddb3bd41be77d356a44574a558b92a7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_084363675bb76eb7448fe9d8bcfd58c1);
#
#
#             var marker_333388a7db49c9117a16d93fda7c1d43 = L.marker(
#                 [53.432018, -2.957987],
#                 {}
#             ).addTo(map_084363675bb76eb7448fe9d8bcfd58c1);
#
#
#         var popup_a910a15903dcb7eda9cae6e98238cdc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2664e75284dbee39bb3ba9dd85488406 = $(`&lt;div id=&quot;html_2664e75284dbee39bb3ba9dd85488406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Stanley Park&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_a910a15903dcb7eda9cae6e98238cdc9.setContent(html_2664e75284dbee39bb3ba9dd85488406);
#
#
#
#         marker_333388a7db49c9117a16d93fda7c1d43.bindPopup(popup_a910a15903dcb7eda9cae6e98238cdc9)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add circle marker
folium.Circle(
    location=[53.431085, -2.960422],
    radius=25,
    popup='Anfield Stadium',
    color='crimson',
    fill=True,
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_084363675bb76eb7448fe9d8bcfd58c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_084363675bb76eb7448fe9d8bcfd58c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_084363675bb76eb7448fe9d8bcfd58c1 = L.map(
#                 &quot;map_084363675bb76eb7448fe9d8bcfd58c1&quot;,
#                 {
#                     center: [53.431085, -2.960422],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ddb3bd41be77d356a44574a558b92a7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_084363675bb76eb7448fe9d8bcfd58c1);
#
#
#             var marker_333388a7db49c9117a16d93fda7c1d43 = L.marker(
#                 [53.432018, -2.957987],
#                 {}
#             ).addTo(map_084363675bb76eb7448fe9d8bcfd58c1);
#
#
#         var popup_a910a15903dcb7eda9cae6e98238cdc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2664e75284dbee39bb3ba9dd85488406 = $(`&lt;div id=&quot;html_2664e75284dbee39bb3ba9dd85488406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Stanley Park&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_a910a15903dcb7eda9cae6e98238cdc9.setContent(html_2664e75284dbee39bb3ba9dd85488406);
#
#
#
#         marker_333388a7db49c9117a16d93fda7c1d43.bindPopup(popup_a910a15903dcb7eda9cae6e98238cdc9)
#         ;
#
#
#
#
#             var circle_6c0472f1ee822b05e3ece8ace230e635 = L.circle(
#                 [53.431085, -2.960422],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_084363675bb76eb7448fe9d8bcfd58c1);
#
#
#         var popup_54bceb2b04de647ce6a7f43c2bfded32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb9de7149fd3cf0fc52fc37d3eeaf25c = $(`&lt;div id=&quot;html_fb9de7149fd3cf0fc52fc37d3eeaf25c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anfield Stadium&lt;/div&gt;`)[0];
#                 popup_54bceb2b04de647ce6a7f43c2bfded32.setContent(html_fb9de7149fd3cf0fc52fc37d3eeaf25c);
#
#
#
#         circle_6c0472f1ee822b05e3ece8ace230e635.bindPopup(popup_54bceb2b04de647ce6a7f43c2bfded32)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Acled Visualization

# %%
# Direct Geopandas/GeoJson

m = folium.Map([4.546647, 22.373178], zoom_start=2, tiles='cartodbpositron')

folium.GeoJson(acled.sample(5)).add_to(m)
m
#m.save('acled.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5c574ee9e8144fac07c2c86ad66173f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5c574ee9e8144fac07c2c86ad66173f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5c574ee9e8144fac07c2c86ad66173f = L.map(
#                 &quot;map_d5c574ee9e8144fac07c2c86ad66173f&quot;,
#                 {
#                     center: [4.546647, 22.373178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b40d414480e5554fcd3e62f4c4d8680 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5c574ee9e8144fac07c2c86ad66173f);
#
#
#
#         function geo_json_11a046c5e0ab7dd42146c70dd318a6c3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_11a046c5e0ab7dd42146c70dd318a6c3 = L.geoJson(null, {
#                 onEachFeature: geo_json_11a046c5e0ab7dd42146c70dd318a6c3_onEachFeature,
#
#         });
#
#         function geo_json_11a046c5e0ab7dd42146c70dd318a6c3_add (data) {
#             geo_json_11a046c5e0ab7dd42146c70dd318a6c3
#                 .addData(data)
#                 .addTo(map_d5c574ee9e8144fac07c2c86ad66173f);
#         }
#             geo_json_11a046c5e0ab7dd42146c70dd318a6c3_add({&quot;bbox&quot;: [-10.8, -15.5392, 45.6357, 31.9664], &quot;features&quot;: [{&quot;bbox&quot;: [12.7848, 12.499, 12.7848, 12.499], &quot;geometry&quot;: {&quot;coordinates&quot;: [12.7848, 12.499], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;8549&quot;, &quot;properties&quot;: {&quot;actor1&quot;: &quot;Military Forces of Nigeria (2015-)&quot;, &quot;actor2&quot;: &quot;Islamic State (West Africa) and/or Boko Haram - Jamatu Ahli is-Sunnah lid-Dawatai wal-Jihad&quot;, &quot;admin1&quot;: &quot;Borno&quot;, &quot;admin2&quot;: &quot;Gubio&quot;, &quot;admin3&quot;: null, &quot;assoc_ac_1&quot;: null, &quot;assoc_acto&quot;: &quot;Civilian JTF: Civilian Joint Task Force&quot;, &quot;country&quot;: &quot;Nigeria&quot;, &quot;data_id&quot;: 6355154, &quot;event_date&quot;: &quot;21 August 2019&quot;, &quot;event_id_c&quot;: &quot;NIG15210&quot;, &quot;event_id_n&quot;: 15210, &quot;event_type&quot;: &quot;Battles&quot;, &quot;fatalities&quot;: 0, &quot;geo_precis&quot;: 1, &quot;inter1&quot;: 1, &quot;inter2&quot;: 2, &quot;interactio&quot;: 12, &quot;iso&quot;: 566, &quot;iso3&quot;: &quot;NGA&quot;, &quot;latitude&quot;: 12.499, &quot;location&quot;: &quot;Gubio&quot;, &quot;longitude&quot;: 12.7848, &quot;notes&quot;: &quot;On August 21st, Boko Haram fighters (indicated by one source has having an IS affiliation) attacked Gubio (Borno state), prompting the army and CJTF presence to flee. One CJTF was abducted in the attack. Upon seizing control of the town, various public a&quot;, &quot;region&quot;: &quot;Western Africa&quot;, &quot;source&quot;: &quot;Vanguard (Nigeria); Nigeria Punch; Sun (Nigeria)&quot;, &quot;source_sca&quot;: &quot;National&quot;, &quot;sub_event_&quot;: &quot;Non-state actor overtakes territory&quot;, &quot;time_preci&quot;: 1, &quot;timestamp&quot;: 1574121955, &quot;year&quot;: 2019}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [45.6357, 2.2949, 45.6357, 2.2949], &quot;geometry&quot;: {&quot;coordinates&quot;: [45.6357, 2.2949], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;20935&quot;, &quot;properties&quot;: {&quot;actor1&quot;: &quot;Al Shabaab&quot;, &quot;actor2&quot;: &quot;AMISOM: African Union Mission in Somalia (2007-)&quot;, &quot;admin1&quot;: &quot;Middle Shabelle&quot;, &quot;admin2&quot;: &quot;Balcad&quot;, &quot;admin3&quot;: null, &quot;assoc_ac_1&quot;: null, &quot;assoc_acto&quot;: null, &quot;country&quot;: &quot;Somalia&quot;, &quot;data_id&quot;: 6134809, &quot;event_date&quot;: &quot;10 February 2019&quot;, &quot;event_id_c&quot;: &quot;SOM27817&quot;, &quot;event_id_n&quot;: 27817, &quot;event_type&quot;: &quot;Explosions/Remote violence&quot;, &quot;fatalities&quot;: 0, &quot;geo_precis&quot;: 1, &quot;inter1&quot;: 2, &quot;inter2&quot;: 8, &quot;interactio&quot;: 28, &quot;iso&quot;: 706, &quot;iso3&quot;: &quot;SOM&quot;, &quot;latitude&quot;: 2.2949, &quot;location&quot;: &quot;Sokolwa&quot;, &quot;longitude&quot;: 45.6357, &quot;notes&quot;: &quot;10 February. An AMISOM soldier was wounded in AS grenade attack at Soqola market.&quot;, &quot;region&quot;: &quot;Eastern Africa&quot;, &quot;source&quot;: &quot;Undisclosed Source&quot;, &quot;source_sca&quot;: &quot;Local partner-Other&quot;, &quot;sub_event_&quot;: &quot;Grenade&quot;, &q

# %%
m = folium.Map([4.546647, 22.373178], zoom_start=2, tiles='cartodbpositron')
acled_sample = acled.sample(1000)
locs_points = zip(acled_sample.geometry.y, acled_sample.geometry.x)
for location in locs_points:
    folium.CircleMarker(location=location, color="red", radius=0.5).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93521499ed39e94d5440293806931245 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93521499ed39e94d5440293806931245&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93521499ed39e94d5440293806931245 = L.map(
#                 &quot;map_93521499ed39e94d5440293806931245&quot;,
#                 {
#                     center: [4.546647, 22.373178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ed8314e135be2ad905c91c8fd59c4f7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93521499ed39e94d5440293806931245);
#
#
#             var circle_marker_d020db27ef8f79b786d22c2f7e809a40 = L.circleMarker(
#                 [-0.5753, 37.3269],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_93521499ed39e94d5440293806931245);
#
#
#             var circle_marker_d30319ae16a7f4fedfff3e4170f90a46 = L.circleMarker(
#                 [0.6534, 29.4956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_93521499ed39e94d5440293806931245);
#
#
#             var circle_marker_92968e69e7544782f35a455f3e210b8d = L.circleMarker(
#                 [8.2516, 46.3157],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_93521499ed39e94d5440293806931245);
#
#
#             var circle_marker_ca631299048ae7da0f5cf40e91681aab = L.circleMarker(
#                 [-18.0127, 31.0756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_93521499ed39e94d5440293806931245);
#
#
#             var circle_marker_97cf0bb9145316d13592c9d029bdd063 = L.circleMarker(
#                 [36.7118, 4.0459],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_93521499ed39e94d5440293806931245);
#
#
#             var circle_marker_c50deaf028ef4ea6e4d718f7d4a45152 = L.circleMarker(
#                 [13.4975, -2.8814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_935

# %%
# Marker Cluster
from folium.plugins import FastMarkerCluster
cmap = folium.Map(location=[4.546647, 22.373178],
                        zoom_start=2,
                        tiles='CartoDB dark_matter')


FastMarkerCluster(data=list(zip(acled_sample.geometry.y.values, acled_sample.geometry.x.values))).add_to(cmap)
folium.LayerControl().add_to(cmap)
cmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1612f231627a7bd6fd226fe95286bb99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1612f231627a7bd6fd226fe95286bb99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1612f231627a7bd6fd226fe95286bb99 = L.map(
#                 &quot;map_1612f231627a7bd6fd226fe95286bb99&quot;,
#                 {
#                     center: [4.546647, 22.373178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cbfd2ba99e3341d478aec9a2df18297 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1612f231627a7bd6fd226fe95286bb99);
#
#
#             var fast_marker_cluster_5a3a97c8fd4c4e643388612328bf1e26 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-0.5753, 37.3269], [0.6534, 29.4956], [8.2516, 46.3157], [-18.0127, 31.0756], [36.7118, 4.0459], [13.4975, -2.8814], [19.6333, 30.4167], [-4.3328, 28.9486], [13.0783, 6.9977], [3.1172, 43.6469], [4.4608, 25.5936], [11.747, 11.9608], [-17.8277, 31.0534], [11.1726, 13.7611], [14.0954, 22.5869], [12.499, 12.7848], [2.39, 45.3833], [14.4417, -11.4341], [15.279000000000002, -1.7004], [-29.3167, 27.4833], [11.6558, 13.4213], [6.1, 10.65], [0.4764, 29.4933], [14.2846, -4.0647], [0.7, 29.5167], [-2.5845, 30.0959], [7.5167, 9.6167], [7.7714, -5.0134], [16.7705, -3.0056], [-26.2167, 28.25], [3.1172, 43.6469], [36.8792, 6.9067], [35.3944, 0.1397], [-16.229, 48.3213], [34.251, 8.747], [-4.325, 15.3222], [11.8277, 39.5916], [-1.2839, 36.7977], [8.75, 38.983000000000004], [15.2275, 1.3135], [34.8504, 5.7281], [11.9702, 8.5044], [35.1939, -0.6414], [-19.6166, 45.4833], [10.7994, 13.4622], [-13.4155, 49.568000000000005], [34.8504, 5.7281], [9.5598, 44.0668], [0.5172, 42.071000000000005], [13.0253, 6.9727], [4.9238, 29.4626], [13.1842, 30.2167], [11.4764, 1.2508], [4.6921, 9.2097], [6.2006, 6.7339], [-24.5333, 32.9833], [7.1149, -7.3866], [36.085, 9.3708], [-28.7168, 24.7409], [-1.1167, 29.0333], [28.438000000000002, -11.1032], [7.5156, 49.3377], [36.1742, 8.7049], [-3.3625, 28.8797], [14.2296, -0.8654], [35.8728, 10.5372], [32.7451, 13.7147], [-26.2667, 27.8667], [36.4621, 7.4261], [36.8, 5.7667], [6.5667, 10.0833], [35.207, 8.683], [14.9961, -3.614], [-3.3181, 29.3654], [-20.9833, 47.15], [8.0014, 47.5672], [14.6667, -17.4441], [-0.7333, 29.0369], [4.25, 30.78], [31.0708, 34.186], [2.0195, 45.31], [4.279, 21.0028], [35.8728, 10.5372], [-17.8333, 31.05], [-15.7833, 35.0], [-3.4744, 29.93], [11.3182, -12.2833], [6.3152, 6.4741], [16.7705, -3.0056], [-3.5594, 28.4389], [-30.4183, 26.8366], [8.2833, 10.6333], [5.556, -0.1969], [32.85, 13.1667], [30.8571, 32.3118], [-26.2023, 28.0436], [-17.6086, 31.1751], [2.0195, 45.31], [-1.8316, 28.7677], [36.2675, 2.75], [31.4684, 14.6312], [0.2098, 29.2716], [14.574000000000002, -3.8359], [10.6159, 13.3849], [-18.7694, 46.0443], [6.0265, 31.0994], [15.5725, 32.5364], [14.5001, -3.9468], [8.48, 47.36], [12.7227, 7.1678], [-26.2023, 28.0436], [15.6972, 1.6309], [-33.9253, 18.4239], [11.7606, 13.2683], [12.9542, 22.8669], [-0.2482, 29.3065], [-31.6732, 29.0333], [36.38, 3.9014], [36.4919, 8.5762], [-26.2023, 28.0436], [-12.9292, 34.2972], [7.5068, 28.3033], [2.9833, 34.1166], [36.7118, 4.0459], [36.7664, 3.4772], [32.7549, 13.1427], [12.1628, 6.6614], [10.2962, 7.7537], [14.3, 33.5833], [-26.3167, 31.1333], [36.0764, 9.0212], [-22.3324, 45.7064], [6.2667, 30.2], [4.3123, 27.7597], [11.3182, -12.2833], [-25.713, 28.3653], [14.3857, -3.0009], [31.0991, -4.013], [-34.0393, 18.6792], [11.2842, 49.1816], [2.048, 45.32], [2.8712, 43.0043], [-2.9761, 29.3686], [2.0678, 45.35], [35.7425, 0.5592], [32.85, 13.1667], [9.34, 28.91], [5.4566, 6.9679], [0.4754, 42.3015], [36.5897, 2.4475], [36.365, 6.6147], [12.6943, 14.3154], [32.4764, 11.7679], [-0.3603, 42.5463], [32.435, 13.6332], [30.6145, -7.8236], [1
